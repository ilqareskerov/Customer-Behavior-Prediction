# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

data = pd.read_excel(r'satisfaction_pred.xlsx')

data
# Out:
#        Age  Income  Number of Purchases  Time Spent on Website Region  \
# 0       64   20856                    5               1.544254  South
# 1       39   69991                    3              22.158004   East
# 2       31   64297                    7              17.411279  South
# 3       40   24440                   10              31.671055  South
# 4       33   49525                    5              43.892811  South
# ...    ...     ...                  ...                    ...    ...
# 31995   31   54536                    1              41.384237  North
# 31996   53   63890                    8              45.561462  North
# 31997   50   71687                   10              38.220942   East
# 31998   38   30655                   19              17.848667  South
# 31999   37   83486                   11              29.039660   East
#
#       Membership Type Subscription Status  Satisfaction Score
# 0                Gold              Active            3.931273
# 1                Gold              Active            8.813718
# 2                Gold              Active            4.423490
# 3                Gold              Active            1.018383
# 4               Basic            Inactive            8.948029
# ...               ...                 ...                 ...
# 31995         Premium            Inactive            5.354833
# 31996            Gold              Active            4.959559
# 31997            Gold            Inactive            0.002699
# 31998           Basic              Active            6.750565
# 31999            Gold              Active            6.901438
#
# [32000 rows x 8 columns]

# %%
data.describe(include='all')
# Out:
#                  Age        Income  Number of Purchases  \
# count   32000.000000  32000.000000         32000.000000
# unique           NaN           NaN                  NaN
# top              NaN           NaN                  NaN
# freq             NaN           NaN                  NaN
# mean       43.415094  60151.562469            10.018812
# std        14.996725  23008.904191             5.500571
# min        18.000000  20004.000000             1.000000
# 25%        30.000000  40365.750000             5.000000
# 50%        43.000000  60158.000000            10.000000
# 75%        56.000000  79996.000000            15.000000
# max        69.000000  99998.000000            19.000000
#
#         Time Spent on Website Region Membership Type Subscription Status  \
# count            32000.000000  32000           32000               32000
# unique                    NaN      4               3                   2
# top                       NaN  North           Basic              Active
# freq                      NaN   8076           10734               16088
# mean                29.944621    NaN             NaN                 NaN
# std                 17.338381    NaN             NaN                 NaN
# min                  0.003282    NaN             NaN                 NaN
# 25%                 14.973681    NaN             NaN                 NaN
# 50%                 29.900169    NaN             NaN                 NaN
# 75%                 44.781076    NaN             NaN                 NaN
# max                 59.999403    NaN             NaN                 NaN
#
#         Satisfaction Score
# count         32000.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean              4.986471
# std               2.887159
# min               0.000272
# 25%               2.480716
# 50%               4.977834
# 75%               7.477885
# max               9.999755

# %%
data.isnull().sum()
# Out:
# Age                      0
# Income                   0
# Number of Purchases      0
# Time Spent on Website    0
# Region                   0
# Membership Type          0
# Subscription Status      0
# Satisfaction Score       0
# dtype: int64

# %%
data = pd.get_dummies(data, drop_first=True)

# %%
data
# Out:
#        Age  Income  Number of Purchases  Time Spent on Website  \
# 0       64   20856                    5               1.544254
# 1       39   69991                    3              22.158004
# 2       31   64297                    7              17.411279
# 3       40   24440                   10              31.671055
# 4       33   49525                    5              43.892811
# ...    ...     ...                  ...                    ...
# 31995   31   54536                    1              41.384237
# 31996   53   63890                    8              45.561462
# 31997   50   71687                   10              38.220942
# 31998   38   30655                   19              17.848667
# 31999   37   83486                   11              29.039660
#
#        Satisfaction Score  Region_North  Region_South  Region_West  \
# 0                3.931273         False          True        False
# 1                8.813718         False         False        False
# 2                4.423490         False          True        False
# 3                1.018383         False          True        False
# 4                8.948029         False          True        False
# ...                   ...           ...           ...          ...
# 31995            5.354833          True         False        False
# 31996            4.959559          True         False        False
# 31997            0.002699         False         False        False
# 31998            6.750565         False          True        False
# 31999            6.901438         False         False        False
#
#        Membership Type_Gold  Membership Type_Premium  \
# 0                      True                    False
# 1                      True                    False
# 2                      True                    False
# 3                      True                    False
# 4                     False                    False
# ...                     ...                      ...
# 31995                 False                     True
# 31996                  True                    False
# 31997                  True                    False
# 31998                 False                    False
# 31999                  True                    False
#
#        Subscription Status_Inactive
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                              True
# ...                             ...
# 31995                          True
# 31996                         False
# 31997                          True
# 31998                         False
# 31999                         False
#
# [32000 rows x 11 columns]

# %%
inputs = data.drop('Satisfaction Score', axis=1)
target = data['Satisfaction Score']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs, target, test_size=0.2, random_state=42)

# %%
from sklearn import metrics

def evaluate(model, x_test, y_test):
    
    y_pred = model.predict(x_test)
    
    mae_test = metrics.mean_absolute_error(y_test, y_pred)
    mse_test = metrics.mean_squared_error(y_test, y_pred)
    rmse_test = np.sqrt(mse_test)
    r2_test = metrics.r2_score(y_test, y_pred)


    y_pred_train = model.predict(x_train)

    mae_train = metrics.mean_absolute_error(y_train, y_pred_train)
    mse_train = metrics.mean_squared_error(y_train, y_pred_train)
    rmse_train = np.sqrt(mse_train)
    r2_train = metrics.r2_score(y_train, y_pred_train)


    results_dict = {
        'Metric': ['MAE', 'MSE', 'RMSE', 'R2'],
        'Train': [mae_train, mse_train, rmse_train, r2_train*100],
        'Test': [mae_test, mse_test, rmse_test, r2_test*100]
    }

    results_df = pd.DataFrame(results_dict)
    
    print(results_df)

# %% [markdown]
# # Default model

# %%
from sklearn.svm import SVR

base_model = SVR(kernel='rbf')
base_model.fit(x_train, y_train)
base_accuracy = evaluate(base_model, x_test, y_test)
# Out:
#   Metric     Train      Test
# 0    MAE  2.500077  2.500571
# 1    MSE  8.341807  8.326677
# 2   RMSE  2.888219  2.885598
# 3     R2 -0.030918 -0.084720

# %% [markdown]
# # Optuna Search

# %%
from sklearn.model_selection import cross_val_score
import optuna

def best_params_for_model(trial):

    param = {
        'C': trial.suggest_loguniform('C', 0.1, 10),  # Regularization parameter
        'kernel': trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']),  # Kernel type
        'degree': trial.suggest_int('degree', 2, 5),  # Degree for polynomial kernel
        'gamma': trial.suggest_categorical('gamma', ['auto', 'scale']),  # Kernel coefficient for 'rbf', 'poly', and 'sigmoid'
        'epsilon': trial.suggest_loguniform('epsilon', 0.01, 1.0)  # Epsilon in the epsilon-SVR model
    }

    svr = SVR(**param)

    score = cross_val_score(svr, x_train, y_train, cv=3, scoring='r2', n_jobs=-1).mean()

    return score

study = optuna.create_study(direction='maximize')
study.optimize(best_params_for_model, n_trials=1)

print('Best trial:')
best_params = study.best_params
print('  Value: {:.3f}'.format(study.best_value))
print('  Params: ', best_params)
# Out:
# [I 2024-06-30 18:29:29,296] A new study created in memory with name: no-name-ccb1e819-536c-4b83-a3c1-45d5c97dd598
# C:\Users\Ilqar\AppData\Local\Temp\ipykernel_14848\2562959290.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'C': trial.suggest_loguniform('C', 0.1, 10),  # Regularization parameter
# C:\Users\Ilqar\AppData\Local\Temp\ipykernel_14848\2562959290.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'epsilon': trial.suggest_loguniform('epsilon', 0.01, 1.0)  # Epsilon in the epsilon-SVR model

# %%
best_svr_model = SVR(**best_params)
best_svr_model.fit(x_train, y_train)

evaluate(best_svr_model, x_test, y_test)

# %% [markdown]
# # Univariate Analysis

# %%
variables = []
train_r2_scores = []
test_r2_scores = []

for i in x_train.columns: 
    X_train_single_var = x_train[[i]]
    X_test_single_var = x_test[[i]]

    best_svr_model.fit(X_train_single_var, y_train)
    y_pred_train_single_var = best_svr_model.predict(X_train_single_var)

    train_r2 = metrics.r2_score(y_train, y_pred_train_single_var)

    y_pred_test_single_var = best_svr_model.predict(X_test_single_var)

    test_r2 = metrics.r2_score(y_test, y_pred_test_single_var)

    variables.append(i)
    train_r2_scores.append(train_r2)
    test_r2_scores.append(test_r2)

results_df = pd.DataFrame({'Variable': variables, 'Train R2': train_r2_scores, 'Test R2': test_r2_scores})

results_df_sorted = results_df.sort_values(by='Test R2', ascending=False)

pd.options.display.float_format = '{:.4f}'.format

results_df_sorted

# %% [markdown]
# # Final inputs

# %%
fin_inputs = data[[]]

x_train, x_test, y_train, y_test = train_test_split(fin_inputs, targets, test_size=0.2, random_state=42)

# %%
best_svr_model.fit(x_train, y_train)

evaluate(best_svr_model, x_test, y_test)
